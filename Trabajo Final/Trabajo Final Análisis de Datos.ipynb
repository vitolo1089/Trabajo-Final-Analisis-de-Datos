# %% [markdown]
# <img SRC="planet.jpg"/>
# </br>
# <center><h1 style="color:#7FFF00"> Trabajo Final Analisis de Datos </h1></center>
# <center><h4 style="color:#00CED1"> U.Castro Carazo </h4></center>
# <center><h6 style="color:#00CED1"> II Cuatrimestre </h6></center>
# <center><h3 style="color:#228B22"> Victor Garcia Ortiz </h3></center>

# %% [markdown]
# </br>
# <p style="font-weight: bold"> Este trabajo lo realizo poniendo en práctica lo aprendido durante este cuatrimestre en donde pudimos aprender cómo utilizar series de datos para trabajar y crear así nuestro set de datos para poder plantearnos y poder dar una respuesta a nuestra pregunta ya sea de negocio o del análisis que queremos desarrollar</p>
#
# <p style="font-weight: bold">La pregunta de negocio para responder es: ¿Como podemos hacer para impactar el cambio climático?</p>
#
# <p style="font-weight: bold">El objetivo principal, es poder proponer a través del análisis de datos una estrategia que nos ayude a mitigar el daño que le hemos causado al medio ambiente </p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cols = ["Ano", "Hidro", "Geotermica", "Eolica", "Biomasa", "Solar", "Termica", "Total"]

#pd.read_excel("TotalgeneracionelectricaenCostaRica.xlsx")

df_TotalgeneracionelectricaenCostaRica = pd.read_excel ("TotalgeneracionelectricaenCostaRica.xlsx", names = cols)

# %%
df_TotalgeneracionelectricaenCostaRica.shape
# Out:
# (11, 8)

# %%
df_TotalgeneracionelectricaenCostaRica.columns
# Out:
# Index(['Ano', 'Hidro', 'Geotermica', 'Eolica', 'Biomasa', 'Solar', 'Termica',
#        'Total'],
#       dtype='object')

# %%
df_TotalgeneracionelectricaenCostaRica.head(15)
# Out:
#       Ano      Hidro  Geotermica    Eolica  Biomasa   Solar   Termica  \
# 0    2010   26144.25     4233.89   1291.23   521.41    0.93   2308.23
# 1    2011   25684.64     4606.35   1492.11   500.37    1.73   3108.03
# 2    2012   26039.52     5049.18   1902.18   643.04    4.67   2989.02
# 3    2013   24663.76     5460.25   1744.45   659.94    8.80   4305.59
# 4    2014   24181.75     5537.29   2645.11   650.24    8.88   3755.53
# 5    2015   29039.71     4952.26   3886.23   645.38    9.12    389.23
# 6    2016   28893.40     4822.25   4130.25   617.42    8.69    694.89
# 7    2017   31237.06     4024.20   4635.64   664.24   16.03    134.70
# 8    2018   30034.43     3486.85   6475.95   625.19  201.76    570.78
# 9    2019   28175.98     5445.27   6466.84   608.57  215.35    344.29
# 10  Total  274094.50    47617.79  34669.99  6135.80  475.96  18600.29
#
#         Total
# 0    34499.95
# 1    35393.24
# 2    36627.60
# 3    36842.78
# 4    36778.79
# 5    38921.94
# 6    39166.91
# ...

# %%
df_TotalgeneracionelectricaenCostaRica.tail(10)
# Out:
#       Ano      Hidro  Geotermica    Eolica  Biomasa   Solar   Termica  \
# 1    2011   25684.64     4606.35   1492.11   500.37    1.73   3108.03
# 2    2012   26039.52     5049.18   1902.18   643.04    4.67   2989.02
# 3    2013   24663.76     5460.25   1744.45   659.94    8.80   4305.59
# 4    2014   24181.75     5537.29   2645.11   650.24    8.88   3755.53
# 5    2015   29039.71     4952.26   3886.23   645.38    9.12    389.23
# 6    2016   28893.40     4822.25   4130.25   617.42    8.69    694.89
# 7    2017   31237.06     4024.20   4635.64   664.24   16.03    134.70
# 8    2018   30034.43     3486.85   6475.95   625.19  201.76    570.78
# 9    2019   28175.98     5445.27   6466.84   608.57  215.35    344.29
# 10  Total  274094.50    47617.79  34669.99  6135.80  475.96  18600.29
#
#         Total
# 1    35393.24
# 2    36627.60
# 3    36842.78
# 4    36778.79
# 5    38921.94
# 6    39166.91
# 7    40711.86
# 8    41394.96
# 9    41256.29
# 10  381594.32

# %%
df_TotalgeneracionelectricaenCostaRica[["Ano", "Solar"]].head(5)
# Out:
#     Ano  Solar
# 0  2010   0.93
# 1  2011   1.73
# 2  2012   4.67
# 3  2013   8.80
# 4  2014   8.88

# %%
eje_x = df_TotalgeneracionelectricaenCostaRica.index.tolist()

eje_y = df_TotalgeneracionelectricaenCostaRica ['Solar'].tolist()

#Creamos la grafica
plt.bar(eje_x, eje_y)

#Leyenda del eje y
plt.ylabel("Años")

##Leyenda en el eje x
plt.xlabel("Energia Producida")

##Titulo del Grafico
plt.title('Cantidad de Eneria Solar Producida')

plt.show()

# %%
df_TotalgeneracionelectricaenCostaRica[["Ano", "Total"]].head(10)
# Out:
#     Ano     Total
# 0  2010  34499.95
# 1  2011  35393.24
# 2  2012  36627.60
# 3  2013  36842.78
# 4  2014  36778.79
# 5  2015  38921.94
# 6  2016  39166.91
# 7  2017  40711.86
# 8  2018  41394.96
# 9  2019  41256.29

# %%
fig, ax = plt.subplots(figsize=(9, 3), subplot_kw=dict(aspect="equal"))
 
data = gf1['Total'].tolist()
Ano = gf1.index.tolist()
 
def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%".format(pct, absolute)
 

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))
 
ax.legend(wedges, estilo,
          title="Total",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
 
plt.setp(autotexts, size=5, weight="bold")
 
ax.set_title("Porcentaje de vehiculos segun estilo")
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 13>()
#       8     return "{:.1f}%".format(pct, absolute)
#      11 wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))
# ---> 13 ax.legend(wedges, estilo,
#      14           title="Total",
#      15           loc="center left",
#      16           bbox_to_anchor=(1, 0, 0.5, 1))
#      18 plt.setp(autotexts, size=5, weight="bold")
#      20 ax.set_title("Porcentaje de vehiculos segun estilo")
#
# NameError: name 'estilo' is not defined

# %% [markdown]
# <li>Profesor hice mi mayor esfuerzo en poner en práctica lo visto y aprendido en las clases, sin embargo tengo que volver repasar la parte de la elección de los datos que voy a cargar para mi Data frame, ya que no supe como plasmar en el programa lo que tenía en mente, ya que lo que quería era crear gráficos donde mostrara por ejemplo tomar el 2012 y generar un gráfico circular donde me dijera cuál de las energías fue la que se produjo en mayor cantidad en ese año
# O hacer un gráfico de barras y poder crear un gráfico que me mostrara en la gráfica de la energía Eólica y me dijera en cuál de los años fue menos la producción de este tipo de energía renovable, sin duda aprendí muchísimo, pero aún me falta mucho más y volveré a reparar las clases, ya que fue un curso de mucho aprendizaje que me sirve para ponerlo en práctica en mi trabajo
# </li>

# %% [markdown]
# <center><h1 style="color:#8A2BE2">Muchas Gracias por todo lo que nos enseño</h1></center>
